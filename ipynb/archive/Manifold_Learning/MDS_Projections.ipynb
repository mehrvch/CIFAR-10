# %% [markdown]
# ## Multi-dimensional scaling (MDS)

# %%
import os
os.chdir('/notebooks/src/CIFAR-10/')
import time
from lib.load_images import load_data
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = load_data()
from sklearn.manifold import TSNE, LocallyLinearEmbedding, Isomap, MDS
import pickle
# Out:
# Using TensorFlow backend.

# %%
## Saving the objects:
# with open('features_imgsize_224.pickle', 'w') as f:  # Python 3: open(..., 'wb')
#     pickle.dump([features_train, features_test], f)

# Getting back the objects:
with open('features_imgsize_224.pickle') as f:  # Python 3: open(..., 'rb')
    features_train, features_test = pickle.load(f)

import numpy as np
X_train = np.squeeze(features_train)
X_test = np.squeeze(features_test)

# %%
start = time.time()
tsne_features = MDS(n_components=2, n_jobs=-1).fit_transform(X_train[0:25000])
end = time.time()
print((end-start) / 60)
np.savez('MDS_features_224', tsne_features=tsne_features)
print("DONE")
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-3-78b654f4af52> in <module>()
#       1 start = time.time()
# ----> 2 tsne_features = MDS(n_components=2, n_jobs=-1).fit_transform(X_train[0:25000])
#       3 end = time.time()
#       4 print((end-start) / 60)
#       5 np.savez('MDS_features_224', tsne_features=tsne_features)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/manifold/mds.pyc in fit_transform(self, X, y, init)
#     423             n_jobs=self.n_jobs, max_iter=self.max_iter, verbose=self.verbose,
#     424             eps=self.eps, random_state=self.random_state,
# --> 425             return_n_iter=True)
#     426
#     427         return self.embedding_
#
# /usr/local/lib/python2.7/dist-packages/sklearn/manifold/mds.pyc in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter)
#     264                 init=init, max_iter=max_iter, verbose=verbose, eps=eps,
#     265                 random_state=seed)
# --> 266             for seed in seeds)
#     267         positions, stress, n_iters = zip(*results)
#     268         best = np.argmin(stress)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python2.7/dist-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# /usr/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     565             return self._value
#     566         else:
# --> 567             raise self._value
#     568
#     569     def _set(self, i, obj):
#
# IOError: [Errno 28] No space left on device

# %% [markdown]
# ### Plot TLSA projections

# %%
(_, y_train), (_, y_test) = cifar10.load_data()
y_train = np.squeeze(y_train)
print('data loaded')

y_train[0:25000].shape

print(tsne_features[:,0])
print(tsne_features[:,1])

from matplotlib import cm

import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
plt.scatter(tsne_features[:,0], tsne_features[:,1], c=(y_train[0:25000]/10.0), s=10, edgecolors='none', cmap=cm.jet)
plt.show()
# Out:
# data loaded
# nan
# nan
